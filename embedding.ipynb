# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\RNN\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[4421, 6518, 6599, 1703],
#  [4421, 6518, 6599, 3505],
#  [4421, 2373, 6599, 3615],
#  [5848, 533, 731, 7326, 5888],
#  [5848, 533, 731, 7326, 3105],
#  [9944, 4421, 1194, 6599, 6251],
#  [2662, 4214, 2550, 7326]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
#from tensorflow.keras.processing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 4421 6518 6599 1703]
#  [   0    0    0    0 4421 6518 6599 3505]
#  [   0    0    0    0 4421 2373 6599 3615]
#  [   0    0    0 5848  533  731 7326 5888]
#  [   0    0    0 5848  533  731 7326 3105]
#  [   0    0    0 9944 4421 1194 6599 6251]
#  [   0    0    0    0 2662 4214 2550 7326]]

# %%
## feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\RNN\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\RNN\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 145ms/step
# array([[[-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [ 0.02873245, -0.00924041,  0.03041634, -0.03666469,
#          -0.04137453,  0.04100188,  0.01704447,  0.01661301,
#          -0.02350903, -0.0005899 ],
#         [-0.01823623,  0.03098002, -0.03847652, -0.02767537,
#           0.00620202, -0.02361964,  0.00332933, -0.01457406,
#           0.0400759 , -0.03250364],
#         [-0.03944816,  0.04522571,  0.0181956 ,  0.00732679,
#          -0.02170776, -0.04494518,  0.00566536, -0.02728318,
#           0.03960229,  0.04347337],
#         [-0.00227679, -0.04654293, -0.0478896 ,  0.01615048,
#          -0.04688808, -0.02382468,  0.01412357, -0.01624965,
#          -0.02491317,  0.03831858]],
#
#        [[-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [ 0.02873245, -0.00924041,  0.03041634, -0.03666469,
#          -0.04137453,  0.04100188,  0.01704447,  0.01661301,
#          -0.02350903, -0.0005899 ],
#         [-0.01823623,  0.03098002, -0.03847652, -0.02767537,
#           0.00620202, -0.02361964,  0.00332933, -0.01457406,
#           0.0400759 , -0.03250364],
#         [-0.03944816,  0.04522571,  0.0181956 ,  0.00732679,
#          -0.02170776, -0.04494518,  0.00566536, -0.02728318,
#           0.03960229,  0.04347337],
#         [-0.00595497,  0.03734901,  0.03407724, -0.01111535,
#          -0.01123818,  0.01464243, -0.01809071,  0.03328231,
#           0.01293231,  0.01824382]],
#
#        [[-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [ 0.02873245, -0.00924041,  0.03041634, -0.03666469,
#          -0.04137453,  0.04100188,  0.01704447,  0.01661301,
#          -0.02350903, -0.0005899 ],
#         [ 0.0261742 ,  0.03174904,  0.00858299, -0.03873454,
#           0.00293537, -0.01753563,  0.01073392,  0.03578898,
#           0.01903148, -0.01911577],
#         [-0.03944816,  0.04522571,  0.0181956 ,  0.00732679,
#          -0.02170776, -0.04494518,  0.00566536, -0.02728318,
#           0.03960229,  0.04347337],
#         [-0.03434414, -0.02841883,  0.0024641 , -0.01842661,
#           0.04549528,  0.01100794, -0.00115622, -0.02301339,
#           0.0303649 , -0.00958056]],
#
#        [[-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.00179834,  0.01296821,  0.00934   ,  0.01845962,
#           0.04810591, -0.01178789, -0.02774636, -0.02162289,
#           0.03525925, -0.01805705],
#         [-0.01363122, -0.01729206, -0.02652662,  0.02155408,
#          -0.02694784, -0.00493066, -0.00850507,  0.01222704,
#          -0.04592843,  0.01836428],
#         [ 0.04952855, -0.02928034, -0.02463932, -0.04076659,
#           0.04099596,  0.0474782 ,  0.04113659, -0.01245638,
#           0.00209819, -0.02479791],
#         [-0.00266379,  0.03569378,  0.01602174, -0.01711655,
#           0.01657057, -0.04388165,  0.0008378 , -0.04273037,
#          -0.04739279, -0.01084883],
#         [ 0.02141989,  0.01471964,  0.00922902,  0.03955081,
#           0.00659835, -0.01150515, -0.02918143, -0.01322297,
#          -0.02930217, -0.03438028]],
#
#        [[-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.00179834,  0.01296821,  0.00934   ,  0.01845962,
#           0.04810591, -0.01178789, -0.02774636, -0.02162289,
#           0.03525925, -0.01805705],
#         [-0.01363122, -0.01729206, -0.02652662,  0.02155408,
#          -0.02694784, -0.00493066, -0.00850507,  0.01222704,
#          -0.04592843,  0.01836428],
#         [ 0.04952855, -0.02928034, -0.02463932, -0.04076659,
#           0.04099596,  0.0474782 ,  0.04113659, -0.01245638,
#           0.00209819, -0.02479791],
#         [-0.00266379,  0.03569378,  0.01602174, -0.01711655,
#           0.01657057, -0.04388165,  0.0008378 , -0.04273037,
#          -0.04739279, -0.01084883],
#         [ 0.01465655, -0.0455607 , -0.01147554,  0.00696798,
#           0.04572542, -0.0042776 , -0.00633156, -0.02788596,
#          -0.01478713,  0.04899183]],
#
#        [[-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.02755218, -0.00873501,  0.00947104, -0.03679025,
#          -0.04518953, -0.01150322, -0.03973598,  0.01142652,
#           0.03860948, -0.00499588],
#         [ 0.02873245, -0.00924041,  0.03041634, -0.03666469,
#          -0.04137453,  0.04100188,  0.01704447,  0.01661301,
#          -0.02350903, -0.0005899 ],
#         [ 0.02146509,  0.0206267 , -0.0365139 , -0.01908103,
#           0.00684627, -0.04896199, -0.02528334,  0.04693044,
#          -0.02261341,  0.02755448],
#         [-0.03944816,  0.04522571,  0.0181956 ,  0.00732679,
#          -0.02170776, -0.04494518,  0.00566536, -0.02728318,
#           0.03960229,  0.04347337],
#         [-0.04527185,  0.04640237,  0.02438584,  0.02458115,
#          -0.03222733,  0.01683738,  0.04026857,  0.01025762,
#           0.02618189, -0.00867968]],
#
#        [[-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.01006087, -0.03929988, -0.01514823,  0.02069249,
#           0.03117787, -0.00727306, -0.04899403,  0.03824521,
#           0.041681  , -0.02061715],
#         [-0.0401016 ,  0.04881728, -0.00204857,  0.01269123,
#           0.02097495,  0.0051714 , -0.00530157, -0.04044389,
#           0.01908589,  0.03926413],
#         [-0.03173818, -0.03122543,  0.01607059,  0.03626846,
#           0.00212314,  0.00941701,  0.03235975,  0.02025867,
#          -0.01454157,  0.01720903],
#         [-0.04808719,  0.03286742, -0.04606978,  0.04302505,
#           0.03863046, -0.00023111, -0.00476495,  0.0256703 ,
#           0.0111784 , -0.0073579 ],
#         [-0.00266379,  0.03569378,  0.01602174, -0.01711655,
#           0.01657057, -0.04388165,  0.0008378 , -0.04273037,
#          -0.04739279, -0.01084883]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 4421, 6518, 6599, 1703])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 49ms/step
# array([[-0.01006087, -0.03929988, -0.01514823,  0.02069249,  0.03117787,
#         -0.00727306, -0.04899403,  0.03824521,  0.041681  , -0.02061715],
#        [-0.01006087, -0.03929988, -0.01514823,  0.02069249,  0.03117787,
#         -0.00727306, -0.04899403,  0.03824521,  0.041681  , -0.02061715],
#        [-0.01006087, -0.03929988, -0.01514823,  0.02069249,  0.03117787,
#         -0.00727306, -0.04899403,  0.03824521,  0.041681  , -0.02061715],
#        [-0.01006087, -0.03929988, -0.01514823,  0.02069249,  0.03117787,
#         -0.00727306, -0.04899403,  0.03824521,  0.041681  , -0.02061715],
#        [ 0.02873245, -0.00924041,  0.03041634, -0.03666469, -0.04137453,
#          0.04100188,  0.01704447,  0.01661301, -0.02350903, -0.0005899 ],
#        [-0.01823623,  0.03098002, -0.03847652, -0.02767537,  0.00620202,
#         -0.02361964,  0.00332933, -0.01457406,  0.0400759 , -0.03250364],
#        [-0.03944816,  0.04522571,  0.0181956 ,  0.00732679, -0.02170776,
#         -0.04494518,  0.00566536, -0.02728318,  0.03960229,  0.04347337],
#        [-0.00227679, -0.04654293, -0.0478896 ,  0.01615048, -0.04688808,
#         -0.02382468,  0.01412357, -0.01624965, -0.02491317,  0.03831858]],
#       dtype=float32)
